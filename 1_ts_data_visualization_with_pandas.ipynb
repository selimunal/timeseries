# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
data=np.random.randn(3,2)
cols=["A","B"]

# %%
idx=pd.date_range("2020-01-01",periods=3,freq="D")
df= pd.DataFrame(data,index=idx, columns=cols)
df
# Out:
#                    A         B
# 2020-01-01  0.340755 -1.978452
# 2020-01-02  0.903260 -1.108183
# 2020-01-03  0.701150 -0.732930

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03'], dtype='datetime64[ns]', freq='D')

# %%
df.index.max()
# Out:
# Timestamp('2020-01-03 00:00:00', freq='D')

# %%
df.index.argmax()
# Out:
# 2

# %%
df.index.min()
# Out:
# Timestamp('2020-01-01 00:00:00', freq='D')

# %%
df.index.argmin()
# Out:
# 0

# %%
my_year = 2017
my_month = 1
my_day = 2
my_hour = 13
my_minute = 30
my_second = 15

# %%
my_date=datetime(my_year,my_month,my_day)
my_date
# Out:
# datetime.datetime(2017, 1, 2, 0, 0)

# %%
my_date_time=datetime(my_year,my_month,my_day,my_hour,my_minute,my_second)
my_date_time
# Out:
# datetime.datetime(2017, 1, 2, 13, 30, 15)

# %%
my_date.day
# Out:
# 2

# %%
np.array(["2016-03-25","2017-05-24","2018-08-09" ], dtype="datetime64")
# Out:
# array(['2016-03-25', '2017-05-24', '2018-08-09'], dtype='datetime64[D]')

# %%
np.arange("2018-06-01","2018-06-23",10,dtype="datetime64[D]")
# Out:
# array(['2018-06-01', '2018-06-11', '2018-06-21'], dtype='datetime64[D]')

# %%
np.arange("1968","2000",dtype="datetime64[Y]")
# Out:
# array(['1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999'],
#       dtype='datetime64[Y]')

# %% [markdown]
# ## Pandas Datetime

# %%
import pandas as pd

# %%
idx=pd.date_range("8/8/2019",periods=8,freq="D")
idx
# Out:
# DatetimeIndex(['2019-08-08', '2019-08-09', '2019-08-10', '2019-08-11',
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
idx=pd.to_datetime(["Jan 01 2019", "1/2/19","05-Jan-2020","01/01/2021"])
idx
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2020-01-05', '2021-01-01'], dtype='datetime64[ns]', freq=None)

# %%
# Create some random data
data = np.random.randn(4,3)
cols = ['A','B',"C"]
print(data)
# Out:
# [[-0.57303547  0.22079076 -1.37184608]
#  [-0.27310696  0.16217158  1.08799654]
#  [-0.88400543  0.03591898  2.40249972]
#  [-1.0643819  -0.96612664  0.60510108]]

# %%
df = pd.DataFrame(data,idx,cols)
df
# Out:
#                    A         B         C
# 2019-01-01 -0.573035  0.220791 -1.371846
# 2019-01-02 -0.273107  0.162172  1.087997
# 2020-01-05 -0.884005  0.035919  2.402500
# 2021-01-01 -1.064382 -0.966127  0.605101

# %%
df.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2020-01-05', '2021-01-01'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## Time Resampling

# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'c:\\Users\\Selim\\My python Stuff\\Time Series Jose Port'

# %%
df = pd.read_csv('./UDEMY_TSA_FINAL/Data/starbucks.csv', index_col='Date', parse_dates=True)

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df.resample(rule="BQ").mean()
# Out:
#                 Close        Volume
# Date
# 2015-03-31  42.033705  1.005831e+07
# 2015-06-30  47.622476  7.375698e+06
# 2015-09-30  52.742539  9.206285e+06
# 2015-12-31  57.498228  8.002620e+06
# 2016-03-31  55.171702  1.093832e+07
# 2016-06-30  54.050434  8.582716e+06
# 2016-09-30  53.350578  8.996589e+06
# 2016-12-30  53.040917  8.753118e+06
# 2017-03-31  54.447013  9.846263e+06
# 2017-06-30  58.427046  8.131475e+06
# 2017-09-29  53.772141  1.017913e+07
# 2017-12-29  55.167005  9.036181e+06
# 2018-03-30  56.678044  1.093577e+07
# 2018-06-29  55.935744  1.043205e+07
# 2018-09-28  52.446013  9.849787e+06
# 2018-12-31  62.428954  1.370105e+07

# %%
df.resample(rule="A").mean()
# Out:
#                 Close        Volume
# Date
# 2015-12-31  50.078100  8.649190e+06
# 2016-12-31  53.891732  9.300633e+06
# 2017-12-31  55.457310  9.296078e+06
# 2018-12-31  56.870005  1.122883e+07

# %%
def first_day(entry):
    if len(entry):
        return entry[0]

# %%
df.resample(rule="A").apply(first_day)
# Out:
#               Close    Volume
# Date
# 2015-12-31  38.0061   6906098
# 2016-12-31  55.0780  13521544
# 2017-12-31  53.1100   7809307
# 2018-12-31  56.3243   7215978

# %%
df.resample(rule="BQ")#.apply(first_day)

# %%
df["Close"].resample("BQ").mean().plot.bar(title='Business quarterly Mean Closing Price for Starbucks',colormap='Dark2');

# %%
from matplotlib import cm

color = cm.inferno_r(np.linspace(.4, .8, 10))

df["Close"].resample("BQ").mean().plot(kind="bar", color=color, stacked=True, title='Business quarterly Mean Closing Price for Starbucks',colormap='Dark2');
# Out:
# c:\Users\Selim\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\plotting\_matplotlib\core.py:245: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   "'color' and 'colormap' cannot be used simultaneously. Using 'color'"
# c:\Users\Selim\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\plotting\_matplotlib\style.py:124: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   "'color' and 'colormap' cannot be used simultaneously. Using 'color'"

# %%
df["Close"].resample("M").max().plot.bar(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Time Shifting

# %%
import pandas as pd

# %%
df.head(), df.tail()
# Out:
# (              Close    Volume
#  Date
#  2015-01-02  38.0061   6906098
#  2015-01-05  37.2781  11623796
#  2015-01-06  36.9748   7664340
#  2015-01-07  37.8848   9732554
#  2015-01-08  38.4961  13170548,
#              Close    Volume
#  Date
#  2018-12-24  60.56   6323252
#  2018-12-26  63.08  16646238
#  2018-12-27  63.20  11308081
#  2018-12-28  63.39   7712127
#  2018-12-31  64.40   7690183)

# %%
df.shift(1).head(), df.shift(1).tail()
# Out:
# (              Close      Volume
#  Date
#  2015-01-02      NaN         NaN
#  2015-01-05  38.0061   6906098.0
#  2015-01-06  37.2781  11623796.0
#  2015-01-07  36.9748   7664340.0
#  2015-01-08  37.8848   9732554.0,
#              Close      Volume
#  Date
#  2018-12-24  61.39  23524888.0
#  2018-12-26  60.56   6323252.0
#  2018-12-27  63.08  16646238.0
#  2018-12-28  63.20  11308081.0
#  2018-12-31  63.39   7712127.0)

# %%
df.shift(-1).head(), df.shift(-1).tail()
# Out:
# (              Close      Volume
#  Date
#  2015-01-02  37.2781  11623796.0
#  2015-01-05  36.9748   7664340.0
#  2015-01-06  37.8848   9732554.0
#  2015-01-07  38.4961  13170548.0
#  2015-01-08  37.2361  27556706.0,
#              Close      Volume
#  Date
#  2018-12-24  63.08  16646238.0
#  2018-12-26  63.20  11308081.0
#  2018-12-27  63.39   7712127.0
#  2018-12-28  64.40   7690183.0
#  2018-12-31    NaN         NaN)

# %%
#shifting everything
df.shift(periods=1,freq="M").head()
## this gathers all data to end of end month
# Out:
#               Close    Volume
# Date
# 2015-01-31  38.0061   6906098
# 2015-01-31  37.2781  11623796
# 2015-01-31  36.9748   7664340
# 2015-01-31  37.8848   9732554
# 2015-01-31  38.4961  13170548

# %%
df.shift(periods=1,freq="M").tail()
# Out:
#             Close    Volume
# Date
# 2018-12-31  60.56   6323252
# 2018-12-31  63.08  16646238
# 2018-12-31  63.20  11308081
# 2018-12-31  63.39   7712127
# 2019-01-31  64.40   7690183

# %% [markdown]
# ## Visualizing

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
def normalize(df_min_max_scaled):
    for column in df_min_max_scaled.columns:
        df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min()) 

    return df_min_max_scaled

# %%
df1=df.copy()

# %%
normalize(df1).plot(alpha=0.5)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df1
# Out:
#                Close    Volume
# Date
# 2015-01-02  0.032867  0.078340
# 2015-01-05  0.009666  0.157132
# 2015-01-06  0.000000  0.091004
# 2015-01-07  0.029001  0.125546
# 2015-01-08  0.048483  0.182965
# ...              ...       ...
# 2018-12-24  0.751643  0.068606
# 2018-12-26  0.831953  0.241013
# 2018-12-27  0.835778  0.151859
# 2018-12-28  0.841833  0.091802
# 2018-12-31  0.874021  0.091436
#
# [1006 rows x 2 columns]

# %%
df
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# ...             ...       ...
# 2018-12-24  60.5600   6323252
# 2018-12-26  63.0800  16646238
# 2018-12-27  63.2000  11308081
# 2018-12-28  63.3900   7712127
# 2018-12-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %%
title="starbucks price"
y_label="Closing price (USD)"
x_label="closing date"

ax=df["Close"].plot(title=title)

# %%
df["Close"]["2017-01-01":"2018-03-01"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Close"]["2017-01-01":"2018-03-01"].min()
# Out:
# 51.2345

# %%
df.loc["2017-01-01":"2018-03-01"].min(), df.loc["2017-01-01":"2018-03-01"].max(),
# Out:
# (Close     5.123450e+01
#  Volume    3.479177e+06
#  dtype: float64,
#  Close     6.249240e+01
#  Volume    5.345479e+07
#  dtype: float64)

# %%
from matplotlib import dates
df["Close"]["2017-01-01":"2018-03-01"].plot()
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))

ax.xaxis.set_major_formatter(dates.DateFormatter("%a-%B-%d"))

# %% [markdown]
# ## rolling and expanding

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.rolling(window=5).mean().head()
# Out:
#                Close     Volume
# Date
# 2015-01-02       NaN        NaN
# 2015-01-05       NaN        NaN
# 2015-01-06       NaN        NaN
# 2015-01-07       NaN        NaN
# 2015-01-08  37.72798  9819467.2

# %%
df["Close"].plot()
df.rolling(window=10).mean()["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Close"].plot()
df.rolling(window=30).mean()["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### expanding

# %%
df["Close"].expanding(min_periods=30).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Close"].expanding(min_periods=1000).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Exercise

# %%
import pandas as pd

# %%
df = pd.read_csv('./UDEMY_TSA_FINAL/Data/monthly_milk_production.csv', encoding='utf8')
title = "Monthly milk production: pounds per cow. Jan '62 - Dec '75"

# %%
df.shape
# Out:
# (168, 2)

# %%
df.head()
# Out:
#       Date  Production
# 0  1962-01         589
# 1  1962-02         561
# 2  1962-03         640
# 3  1962-04         656
# 4  1962-05         727

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        168 non-null    datetime64[ns]
#  1   Production  168 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.8 KB

# %%
df.head()
# Out:
#         Date  Production
# 0 1962-01-01         589
# 1 1962-02-01         561
# 2 1962-03-01         640
# 3 1962-04-01         656
# 4 1962-05-01         727

# %%
df.index=df["Date"]

# %%
df=df.drop("Date",axis=1)

# %%
df
# Out:
#             Production
# Date
# 1962-01-01         589
# 1962-02-01         561
# 1962-03-01         640
# 1962-04-01         656
# 1962-05-01         727
# ...                ...
# 1975-08-01         858
# 1975-09-01         817
# 1975-10-01         827
# 1975-11-01         797
# 1975-12-01         843
#
# [168 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Month"]=df.index.month
df.head()
# Out:
#             Production  Month
# Date
# 1962-01-01         589      1
# 1962-02-01         561      2
# 1962-03-01         640      3
# 1962-04-01         656      4
# 1962-05-01         727      5

# %%
df.groupby("Month").boxplot(subplots=False,rot=45);

# %%
df.index.strftime('%B')
# Out:
# Index(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October',
#        ...
#        'March', 'April', 'May', 'June', 'July', 'August', 'September',
#        'October', 'November', 'December'],
#       dtype='object', name='Date', length=168)

# %%
df.boxplot(column="Production",by="Month")
# Out:
# <AxesSubplot:title={'center':'Production'}, xlabel='Month'>

# %% [markdown]
# ### Exercise 2

# %%
pwd
# Out:
# 'c:\\Users\\Selim\\My python Stuff\\Time Series Jose Port'

# %%
df=pd.read_csv("./UDEMY_TSA_FINAL/Data/UMTMVS.csv")

# %%
df.head()
# Out:
#          DATE    UMTMVS
# 0  1992-01-01  209438.0
# 1  1992-02-01  232679.0
# 2  1992-03-01  249673.0
# 3  1992-04-01  239666.0
# 4  1992-05-01  243231.0

# %%
# you could use
# df=df.set_index("DATE")

df.index=df["DATE"]
df=df.drop("DATE",axis=1)
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
# converting datetime index 
df.index=pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=325, freq=None)

# %%
df.plot();

# %%
#percentage decrease

df.pct_change(periods=12)["2008-01":"2009-01"]["2009-01"]["UMTMVS"].item()*100
# Out:
# C:\Users\Selim\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
# -22.02277548131305

# %%
#percent increase between 2009 and 2019
100*(df.loc["2019-01-01"]-df.loc["2009-01-01"])/df.loc["2009-01-01"]
# Out:
# UMTMVS    38.472149
# dtype: float64

# %%
df["2015-01-01":"2015-12-31"].min().item()
# Out:
# 424095.0

# %%
row_index, col_index = (df == df["2015":"2016"].min().item()).values.nonzero()
row_index, col_index
# Out:
# (array([288], dtype=int64), array([0], dtype=int64))

# %%
df.iloc[288]
# Out:
# UMTMVS    398051.0
# Name: 2016-01-01 00:00:00, dtype: float64

# %%
(df==df["2005":].min().item()).values.nonzero()
df.iloc[204]
# Out:
# UMTMVS    337101.0
# Name: 2009-01-01 00:00:00, dtype: float64

# %%
#least value after 2015
df.loc["2005-01-01":].idxmin()
# Out:
# UMTMVS   2009-01-01
# dtype: datetime64[ns]

# %%
df.nlargest(6,"UMTMVS")
# Out:
#               UMTMVS
# DATE
# 2018-08-01  529157.0
# 2018-10-01  527031.0
# 2018-06-01  525660.0
# 2018-03-01  518285.0
# 2018-09-01  516992.0
# 2014-06-01  516935.0

# %%
# what 6 months have the hightest value
df.sort_values(by="UMTMVS", ascending=False).head(6)
# Out:
#               UMTMVS
# DATE
# 2018-08-01  529157.0
# 2018-10-01  527031.0
# 2018-06-01  525660.0
# 2018-03-01  518285.0
# 2018-09-01  516992.0
# 2014-06-01  516935.0

# %%
df["2008-01"].values-df["2009-01"].values
# Out:
# C:\Users\Selim\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
# array([[95206.]])

# %%
#lost millions in 2008
df.loc["2008-01-01"]-df.loc["2009-01-01"]
# Out:
# UMTMVS    95206.0
# dtype: float64

# %%
df["UMTMVS"].resample("Y").mean().plot.bar();

# %%
df["UMTMVS"].resample("Y").mean()
# Out:
# DATE
# 1992-12-31    242002.000000
# 1993-12-31    251708.083333
# 1994-12-31    269842.666667
# 1995-12-31    289973.083333
# 1996-12-31    299765.666667
# 1997-12-31    319558.250000
# 1998-12-31    324984.416667
# 1999-12-31    335990.583333
# 2000-12-31    350715.333333
# 2001-12-31    330874.916667
# 2002-12-31    326226.916667
# 2003-12-31    334615.666667
# 2004-12-31    359080.833333
# 2005-12-31    395173.083333
# 2006-12-31    417962.666667
# 2007-12-31    443288.083333
# 2008-12-31    455749.500000
# 2009-12-31    368648.250000
# 2010-12-31    409273.083333
# 2011-12-31    457657.833333
# 2012-12-31    474727.333333
# 2013-12-31    484145.416667
# 2014-12-31    490629.916667
# 2015-12-31    459918.333333
# 2016-12-31    446224.500000
# 2017-12-31    467076.333333
# 2018-12-31    499964.166667
# 2019-12-31    466791.000000
# Freq: A-DEC, Name: UMTMVS, dtype: float64

# %%
df.groupby(df.index.year).mean().head()#.boxplot(subplots=False,rot=45);
# Out:
#              UMTMVS
# DATE
# 1992  242002.000000
# 1993  251708.083333
# 1994  269842.666667
# 1995  289973.083333
# 1996  299765.666667

# %%
# biggest increase in mean value from the previours year"s mean value
yearly_data=df.resample("Y").mean()
yearly_data_shift=yearly_data.shift(1)
change=yearly_data-yearly_data_shift
change["UMTMVS"].idxmax()
# Out:
# Timestamp('2011-12-31 00:00:00', freq='A-DEC')

# %%
df.groupby(df.index.year).mean().diff().max()
# Out:
# UMTMVS    48384.75
# dtype: float64

# %%
df.groupby(df.index.year).mean().diff().idxmax()
# Out:
# UMTMVS    2011
# dtype: int64

# %%
#yearly rolling mean on top of the original data

df.plot()
df.rolling(window=12).mean()["UMTMVS"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
#the value is peaked in 2008, how many months did it take to surpass this peak 

df["2008"].idxmax().dt.to_period("M")
# Out:
# C:\Users\Selim\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
# UMTMVS    2008-06
# dtype: period[M]

# %%
(df["2009":]>df["2008"].max()).idxmax().dt.to_period("M")
# Out:
# C:\Users\Selim\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
# UMTMVS    2014-03
# dtype: period[M]

# %%
((df["2009":]>df["2008"].max()).idxmax().dt.to_period("M"))-(df["2008"].idxmax().dt.to_period("M"))
# Out:
# C:\Users\Selim\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
# UMTMVS    <69 * MonthEnds>
# dtype: object

# %%
df2008=df.loc["2008-01-01":"2009-01-01"]

# %%
df2008.idxmax(), df2008.max()
# Out:
# (UMTMVS   2008-06-01
#  dtype: datetime64[ns],
#  UMTMVS    510081.0
#  dtype: float64)
